# %% [markdown]
# # Sentiment Analysis
#
# ## Using XGBoost in SageMaker
#
# _Deep Learning Nanodegree Program | Deployment_
#
# ---
#
# As our first example of using Amazon's SageMaker service we will construct a random tree model to predict the sentiment of a movie review. You may have seen a version of this example in a pervious lesson although it would have been done using the sklearn package. Instead, we will be using the XGBoost package as it is provided to us by Amazon.
#
# ## Instructions
#
# Some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this notebook. You will not need to modify the included code beyond what is requested. Sections that begin with '**TODO**' in the header indicate that you need to complete or implement some portion within them. Instructions will be provided for each section and the specifics of the implementation are marked in the code block with a `# TODO: ...` comment. Please be sure to read the instructions carefully!
#
# In addition to implementing code, there will be questions for you to answer which relate to the task and your implementation. Each section where you will answer a question is preceded by a '**Question:**' header. Carefully read each question and provide your answer below the '**Answer:**' header by editing the Markdown cell.
#
# > **Note**: Code and Markdown cells can be executed using the **Shift+Enter** keyboard shortcut. In addition, a cell can be edited by typically clicking it (double-click for Markdown cells) or by pressing **Enter** while it is highlighted.

# %% [markdown]
# ## Step 1: Downloading the data
#
# The dataset we are going to use is very popular among researchers in Natural Language Processing, usually referred to as the [IMDb dataset](http://ai.stanford.edu/~amaas/data/sentiment/). It consists of movie reviews from the website [imdb.com](http://www.imdb.com/), each labeled as either '**pos**itive', if the reviewer enjoyed the film, or '**neg**ative' otherwise.
#
# > Maas, Andrew L., et al. [Learning Word Vectors for Sentiment Analysis](http://ai.stanford.edu/~amaas/data/sentiment/). In _Proceedings of the 49th Annual Meeting of the Association for Computational Linguistics: Human Language Technologies_. Association for Computational Linguistics, 2011.
#
# We begin by using some Jupyter Notebook magic to download and extract the dataset.

# %%
# %mkdir ../data
# !wget -O ../data/aclImdb_v1.tar.gz http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# !tar -zxf ../data/aclImdb_v1.tar.gz -C ../data
# Out:
# mkdir: cannot create directory ‘../data’: File exists
# --2018-10-12 05:58:51--  http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# Resolving ai.stanford.edu (ai.stanford.edu)... 171.64.68.10
# Connecting to ai.stanford.edu (ai.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84125825 (80M) [application/x-gzip]
# Saving to: ‘../data/aclImdb_v1.tar.gz’
#
# ../data/aclImdb_v1. 100%[===================>]  80.23M  21.9MB/s    in 4.0s
#
# 2018-10-12 05:58:55 (20.0 MB/s) - ‘../data/aclImdb_v1.tar.gz’ saved [84125825/84125825]

# %% [markdown]
# ## Step 2: Preparing the data
#
# The data we have downloaded is split into various files, each of which contains a single review. It will be much easier going forward if we combine these individual files into two large files, one for training and one for testing.

# %%
import os
import glob

def read_imdb_data(data_dir='../data/aclImdb'):
    data = {}
    labels = {}
    
    for data_type in ['train', 'test']:
        data[data_type] = {}
        labels[data_type] = {}
        
        for sentiment in ['pos', 'neg']:
            data[data_type][sentiment] = []
            labels[data_type][sentiment] = []
            
            path = os.path.join(data_dir, data_type, sentiment, '*.txt')
            files = glob.glob(path)
            
            for f in files:
                with open(f) as review:
                    data[data_type][sentiment].append(review.read())
                    # Here we represent a positive review by '1' and a negative review by '0'
                    labels[data_type][sentiment].append(1 if sentiment == 'pos' else 0)
                    
            assert len(data[data_type][sentiment]) == len(labels[data_type][sentiment]), \
                    "{}/{} data size does not match labels size".format(data_type, sentiment)
                
    return data, labels

# %%
data, labels = read_imdb_data()
print("IMDB reviews: train = {} pos / {} neg, test = {} pos / {} neg".format(
            len(data['train']['pos']), len(data['train']['neg']),
            len(data['test']['pos']), len(data['test']['neg'])))
# Out:
# IMDB reviews: train = 12500 pos / 12500 neg, test = 12500 pos / 12500 neg

# %%
from sklearn.utils import shuffle

def prepare_imdb_data(data, labels):
    """Prepare training and test sets from IMDb movie reviews."""
    
    #Combine positive and negative reviews and labels
    data_train = data['train']['pos'] + data['train']['neg']
    data_test = data['test']['pos'] + data['test']['neg']
    labels_train = labels['train']['pos'] + labels['train']['neg']
    labels_test = labels['test']['pos'] + labels['test']['neg']
    
    #Shuffle reviews and corresponding labels within training and test sets
    data_train, labels_train = shuffle(data_train, labels_train)
    data_test, labels_test = shuffle(data_test, labels_test)
    
    # Return a unified training data, test data, training labels, test labets
    return data_train, data_test, labels_train, labels_test

# %%
train_X, test_X, train_y, test_y = prepare_imdb_data(data, labels)
print("IMDb reviews (combined): train = {}, test = {}".format(len(train_X), len(test_X)))
# Out:
# IMDb reviews (combined): train = 25000, test = 25000

# %%
train_X[100]
# Out:
# 'This horror movie is really weak...that is if this is the correct movie I am commenting on. Nothing really terrible goes on as a family adopts a cute little German Shepard pup. I had a German Shepard and it is a really good dog. I did not get the idea to get one from this movie though, but rather from the comedy "K-9". That is another story all together though. This movie really doesn\'t have much horror at all as the most horrific scene is at the end and it looks really cheesy. Also, we see a guy almost put his hand into a lawn mower. That is about it. The father suspects something though, as his family seems to be getting rather strange, somewhere he finds out if you hold a mirror to them while they are sleeping you can see if they are possessed. All in all a really weak horror movie even by television standards...television movies that do work are out there as "This House Possessed" is pretty good and there is another haunted house movie about a woman and these strange creatures that is also rather good. This one is really rather dull.'

# %% [markdown]
# ## Step 3: Processing the data
#
# Now that we have our training and testing datasets merged and ready to use, we need to start processing the raw data into something that will be useable by our machine learning algorithm. To begin with, we remove any html formatting that may appear in the reviews and perform some standard natural language processing in order to homogenize the data.

# %%
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
from nltk.stem.porter import *
stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import re
from bs4 import BeautifulSoup

def review_to_words(review):
    text = BeautifulSoup(review, "html.parser").get_text() # Remove HTML tags
    text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower()) # Convert to lower case
    words = text.split() # Split string into words
    words = [w for w in words if w not in stopwords.words("english")] # Remove stopwords
    words = [PorterStemmer().stem(w) for w in words] # stem
    
    return words

# %%
import pickle

cache_dir = os.path.join("../cache", "sentiment_analysis")  # where to store cache files
os.makedirs(cache_dir, exist_ok=True)  # ensure cache directory exists

def preprocess_data(data_train, data_test, labels_train, labels_test,
                    cache_dir=cache_dir, cache_file="preprocessed_data.pkl"):
    """Convert each review to words; read from cache if available."""

    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = pickle.load(f)
            print("Read preprocessed data from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Preprocess training and test data to obtain words for each review
        #words_train = list(map(review_to_words, data_train))
        #words_test = list(map(review_to_words, data_test))
        words_train = [review_to_words(review) for review in data_train]
        words_test = [review_to_words(review) for review in data_test]
        
        # Write to cache file for future runs
        if cache_file is not None:
            cache_data = dict(words_train=words_train, words_test=words_test,
                              labels_train=labels_train, labels_test=labels_test)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                pickle.dump(cache_data, f)
            print("Wrote preprocessed data to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        words_train, words_test, labels_train, labels_test = (cache_data['words_train'],
                cache_data['words_test'], cache_data['labels_train'], cache_data['labels_test'])
    
    return words_train, words_test, labels_train, labels_test

# %%
# Preprocess data
train_X, test_X, train_y, test_y = preprocess_data(train_X, test_X, train_y, test_y)
# Out:
# Wrote preprocessed data to cache file: preprocessed_data.pkl

# %% [markdown]
# ### Extract Bag-of-Words features
#
# For the model we will be implementing, rather than using the reviews directly, we are going to transform each review into a Bag-of-Words feature representation. Keep in mind that 'in the wild' we will only have access to the training set so our transformer can only use the training set to construct a representation.

# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.externals import joblib
# joblib is an enhanced version of pickle that is more efficient for storing NumPy arrays

def extract_BoW_features(words_train, words_test, vocabulary_size=5000,
                         cache_dir=cache_dir, cache_file="bow_features.pkl"):
    """Extract Bag-of-Words for a given set of documents, already preprocessed into words."""
    
    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = joblib.load(f)
            print("Read features from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Fit a vectorizer to training documents and use it to transform them
        # NOTE: Training documents have already been preprocessed and tokenized into words;
        #       pass in dummy functions to skip those steps, e.g. preprocessor=lambda x: x
        vectorizer = CountVectorizer(max_features=vocabulary_size,
                preprocessor=lambda x: x, tokenizer=lambda x: x)  # already preprocessed
        features_train = vectorizer.fit_transform(words_train).toarray()

        # Apply the same vectorizer to transform the test documents (ignore unknown words)
        features_test = vectorizer.transform(words_test).toarray()
        
        # NOTE: Remember to convert the features using .toarray() for a compact representation
        
        # Write to cache file for future runs (store vocabulary as well)
        if cache_file is not None:
            vocabulary = vectorizer.vocabulary_
            cache_data = dict(features_train=features_train, features_test=features_test,
                             vocabulary=vocabulary)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                joblib.dump(cache_data, f)
            print("Wrote features to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        features_train, features_test, vocabulary = (cache_data['features_train'],
                cache_data['features_test'], cache_data['vocabulary'])
    
    # Return both the extracted features as well as the vocabulary
    return features_train, features_test, vocabulary

# %%
# Extract Bag of Words features for both training and test datasets
train_X, test_X, vocabulary = extract_BoW_features(train_X, test_X)
# Out:
# Wrote features to cache file: bow_features.pkl

# %% [markdown]
# ## Step 4: Classification using XGBoost
#
# Now that we have created the feature representation of our training (and testing) data, it is time to start setting up and using the XGBoost classifier provided by SageMaker.
#
# ### Writing the dataset
#
# The XGBoost classifier that we will be using requires the dataset to be written to a file and stored using Amazon S3. To do this, we will start by splitting the training dataset into two parts, the data we will train the model with and a validation set. Then, we will write those datasets to a file and upload the files to S3. In addition, we will write the test set input to a file and upload the file to S3. This is so that we can use SageMakers Batch Transform functionality to test our model once we've fit it.

# %%
import pandas as pd

val_X = pd.DataFrame(train_X[:10000])
train_X = pd.DataFrame(train_X[10000:])

val_y = pd.DataFrame(train_y[:10000])
train_y = pd.DataFrame(train_y[10000:])

# %% [markdown]
# The documentation for the XGBoost algorithm in SageMaker requires that the saved datasets should contain no headers or index and that for the training and validation data, the label should occur first for each sample.
#
# For more information about this and other algorithms, the SageMaker developer documentation can be found on __[Amazon's website.](https://docs.aws.amazon.com/sagemaker/latest/dg/)__

# %%
# First we make sure that the local directory in which we'd like to store the training and validation csv files exists.
data_dir = '../data/xgboost'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# %%
# First, save the test data to test.csv in the data_dir directory. Note that we do not save the associated ground truth
# labels, instead we will use them later to compare with our model output.

# Solution:
# The test data shouldn't contain the ground truth labels as they are what the model is
# trying to predict. We will end up using them afterward to compare the predictions to.
# pd.concat([test_y, test_X], axis=1).to_csv(os.path.join(data_dir, 'test.csv'), header=False, index=False)
pd.DataFrame(test_X).to_csv(os.path.join(data_dir, 'test.csv'), header=False, index=False)

pd.concat([val_y, val_X], axis=1).to_csv(os.path.join(data_dir, 'validation.csv'), header=False, index=False)
pd.concat([train_y, train_X], axis=1).to_csv(os.path.join(data_dir, 'train.csv'), header=False, index=False)

# %%
# To save a bit of memory we can set text_X, train_X, val_X, train_y and val_y to None.

test_X = train_X = val_X = train_y = val_y = None

# %% [markdown]
# ### Uploading Training / Validation files to S3
#
# Amazon's S3 service allows us to store files that can be access by both the built-in training models such as the XGBoost model we will be using as well as custom models such as the one we will see a little later.
#
# For this, and most other tasks we will be doing using SageMaker, there are two methods we could use. The first is to use the low level functionality of SageMaker which requires knowing each of the objects involved in the SageMaker environment. The second is to use the high level functionality in which certain choices have been made on the user's behalf. The low level approach benefits from allowing the user a great deal of flexibility while the high level approach makes development much quicker. For our purposes we will opt to use the high level approach although using the low-level approach is certainly an option.
#
# Recall the method `upload_data()` which is a member of object representing our current SageMaker session. What this method does is upload the data to the default bucket (which is created if it does not exist) into the path described by the key_prefix variable. To see this for yourself, once you have uploaded the data files, go to the S3 console and look to see where the files have been uploaded.
#
# For additional resources, see the __[SageMaker API documentation](http://sagemaker.readthedocs.io/en/latest/)__ and in addition the __[SageMaker Developer Guide.](https://docs.aws.amazon.com/sagemaker/latest/dg/)__

# %%
import sagemaker

session = sagemaker.Session() # Store the current SageMaker session

# S3 prefix (which folder will we use)
prefix = 'sentiment-xgboost'

test_location = session.upload_data(os.path.join(data_dir, 'test.csv'), key_prefix=prefix)
val_location = session.upload_data(os.path.join(data_dir, 'validation.csv'), key_prefix=prefix)
train_location = session.upload_data(os.path.join(data_dir, 'train.csv'), key_prefix=prefix)
# Out:
# INFO:sagemaker:Created S3 bucket: sagemaker-us-east-1-440180731255

# %% [markdown]
# ### (TODO) Creating a hypertuned XGBoost model
#
# Now that the data has been uploaded it is time to create the XGBoost model. As in the Boston Housing notebook, the first step is to create an estimator object which will be used as the *base* of your hyperparameter tuning job.

# %%
from sagemaker import get_execution_role

# Our current execution role is require when creating the model as the training
# and inference code will need to access the model artifacts.
role = get_execution_role()

# %%
# We need to retrieve the location of the container which is provided by Amazon for using XGBoost.
# As a matter of convenience, the training and inference code both use the same container.
from sagemaker.amazon.amazon_estimator import get_image_uri

container = get_image_uri(session.boto_region_name, 'xgboost')

# %%
# TODO: Create a SageMaker estimator using the container location determined in the previous cell.
#       It is recommended that you use a single training instance of type ml.m4.xlarge. It is also
#       recommended that you use 's3://{}/{}/output'.format(session.default_bucket(), prefix) as the
#       output path.

xgb = None

# TODO: Set the XGBoost hyperparameters in the xgb object. Don't forget that in this case we have a binary
#       label so we should be using the 'binary:logistic' objective.
xgb = sagemaker.estimator.Estimator(container, # The location of the container we wish to use
                                    role,                                    # What is our current IAM Role
                                    train_instance_count=1,                  # How many compute instances
                                    train_instance_type='ml.m4.xlarge',      # What kind of compute instances
                                    output_path='s3://{}/{}/output'.format(session.default_bucket(), prefix),
                                    sagemaker_session=session)

xgb.set_hyperparameters(max_depth=5,
                        eta=0.2,
                        gamma=4,
                        min_child_weight=6,
                        subsample=0.8,
                        silent=0,
                        objective='binary:logistic',
                        early_stopping_rounds=10,
                        num_round=500)

# %% [markdown]
# ### (TODO) Create the hyperparameter tuner
#
# Now that the base estimator has been set up we need to construct a hyperparameter tuner object which we will use to request SageMaker construct a hyperparameter tuning job.

# %%
# First, make sure to import the relevant objects used to construct the tuner
from sagemaker.tuner import IntegerParameter, ContinuousParameter, HyperparameterTuner

# TODO: Create the hyperparameter tuner object

xgb_hyperparameter_tuner = HyperparameterTuner(estimator = xgb, # The estimator object to use as the basis for the training jobs.
                                               objective_metric_name = 'validation:rmse', # The metric used to compare trained models.
                                               objective_type = 'Minimize', # Whether we wish to minimize or maximize the metric.
                                               max_jobs = 20, # The total number of models to train
                                               max_parallel_jobs = 3, # The number of models to train in parallel
                                               hyperparameter_ranges = {
                                                    'max_depth': IntegerParameter(3, 12),
                                                    'eta'      : ContinuousParameter(0.05, 0.5),
                                                    'min_child_weight': IntegerParameter(2, 8),
                                                    'subsample': ContinuousParameter(0.5, 0.9),
                                                    'gamma': ContinuousParameter(0, 10),
                                               })

# %% [markdown]
# ### Fit the hyperparameter tuner
#
# Now that the hyperparameter tuner object has been constructed, it is time to fit the various models and find the best performing model.

# %%
s3_input_train = sagemaker.s3_input(s3_data=train_location, content_type='csv')
s3_input_validation = sagemaker.s3_input(s3_data=val_location, content_type='csv')

# %%
xgb_hyperparameter_tuner.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# INFO:sagemaker:Creating hyperparameter tuning job with name: xgboost-181012-0648

# %% [markdown]
# Remember that the tuning job is constructed and run in the background so if we want to see the progress of our training job we need to call the `wait()` method.

# %%
xgb_hyperparameter_tuner.wait()
# Out:
# ..................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................!

# %% [markdown]
# ### (TODO) Testing the model
#
# Now that we've run our hyperparameter tuning job, it's time to see how well the best performing model actually performs. To do this we will use SageMakers Batch Transform functionality. Batch Transform is a convenient way to perform inference on a large dataset in a way that is not realtime. That is, we don't necessarily need to use our model's results immediately and instead we can peform inference on a large number of samples. An example of this in industry might be peforming an end of month report. This method of inference can also be useful to us as it means to can perform inference on our entire test set.
#
# Remember that in order to create a transformer object to perform the batch transform job, we need a trained estimator object. We can do that using the `attach()` method, creating an estimator object which is attached to the best trained job.

# %%
# TODO: Create a new estimator object attached to the best training job found during hyperparameter tuning

xgb_attached = sagemaker.estimator.Estimator.attach(xgb_hyperparameter_tuner.best_training_job())
# Out:
# 2018-10-12 08:50:18 Starting - Preparing the instances for training
# 2018-10-12 08:52:19 Downloading - Downloading input data
# 2018-10-12 08:52:30 Training - Training image download completed. Training in progress.
# 2018-10-12 09:15:23 Uploading - Uploading generated training model
# 2018-10-12 09:15:29 Completed - Training job completedArguments: train
# [2018-10-12:08:52:49:INFO] Running standalone xgboost training.
# [2018-10-12:08:52:49:INFO] Setting up HPO optimized metric to be : rmse
# [2018-10-12:08:52:49:INFO] File size need to be processed in the node: 238.47mb. Available memory size in the node: 8386.36mb
# [2018-10-12:08:52:49:INFO] Determined delimiter of CSV input is ','
# [08:52:49] S3DistributionType set as FullyReplicated
# [08:52:52] 15000x5000 matrix with 75000000 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2018-10-12:08:52:52:INFO] Determined delimiter of CSV input is ','
# [08:52:52] S3DistributionType set as FullyReplicated
# [08:52:53] 10000x5000 matrix with 50000000 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [08:52:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 192 extra nodes, 32 pruned nodes, max_depth=11
# [0]#011train-rmse:0.488276#011validation-rmse:0.488937
# Multiple eval metrics have been passed: 'validation-rmse' will be used for early stopping.
#
# Will train until validation-rmse hasn't improved in 10 rounds.
# [08:53:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 40 pruned nodes, max_depth=11
# [1]#011train-rmse:0.477879#011validation-rmse:0.479173
# [08:53:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 178 extra nodes, 30 pruned nodes, max_depth=11
# [2]#011train-rmse:0.468482#011validation-rmse:0.470546
# [08:53:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 38 pruned nodes, max_depth=11
# [3]#011train-rmse:0.460118#011validation-rmse:0.462999
# [08:53:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 36 pruned nodes, max_depth=11
# [4]#011train-rmse:0.452489#011validation-rmse:0.456412
# [08:53:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 32 pruned nodes, max_depth=11
# [5]#011train-rmse:0.445648#011validation-rmse:0.450395
# [08:53:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 40 pruned nodes, max_depth=11
# [6]#011train-rmse:0.439345#011validation-rmse:0.444746
# [08:53:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 188 extra nodes, 22 pruned nodes, max_depth=11
# [7]#011train-rmse:0.433538#011validation-rmse:0.439819
# [08:53:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 172 extra nodes, 26 pruned nodes, max_depth=11
# [8]#011train-rmse:0.428272#011validation-rmse:0.435245
# [08:53:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 46 pruned nodes, max_depth=11
# [9]#011train-rmse:0.42347#011validation-rmse:0.43108
# [08:53:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 40 pruned nodes, max_depth=11
# [10]#011train-rmse:0.41881#011validation-rmse:0.427259
# [08:53:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 30 pruned nodes, max_depth=11
# [11]#011train-rmse:0.414531#011validation-rmse:0.423801
# [08:53:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 128 extra nodes, 28 pruned nodes, max_depth=11
# [12]#011train-rmse:0.410629#011validation-rmse:0.420437
# [08:53:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 36 pruned nodes, max_depth=11
# [13]#011train-rmse:0.406603#011validation-rmse:0.417483
# [08:53:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 28 pruned nodes, max_depth=11
# [14]#011train-rmse:0.402976#011validation-rmse:0.414662
# [08:53:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 26 pruned nodes, max_depth=11
# [15]#011train-rmse:0.399347#011validation-rmse:0.411889
# [08:53:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 24 pruned nodes, max_depth=11
# [16]#011train-rmse:0.395775#011validation-rmse:0.408937
# [08:53:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 22 pruned nodes, max_depth=11
# [17]#011train-rmse:0.392691#011validation-rmse:0.40638
# [08:53:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 38 pruned nodes, max_depth=11
# [18]#011train-rmse:0.38974#011validation-rmse:0.404184
# [08:53:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 44 pruned nodes, max_depth=11
# [19]#011train-rmse:0.386888#011validation-rmse:0.402023
# [08:53:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 36 pruned nodes, max_depth=11
# [20]#011train-rmse:0.384208#011validation-rmse:0.399923
# [08:53:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 24 pruned nodes, max_depth=11
# [21]#011train-rmse:0.381533#011validation-rmse:0.397849
# [08:53:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 18 pruned nodes, max_depth=11
# [22]#011train-rmse:0.378775#011validation-rmse:0.395595
# [08:54:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 40 pruned nodes, max_depth=11
# [23]#011train-rmse:0.376043#011validation-rmse:0.393525
# [08:54:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 32 pruned nodes, max_depth=11
# [24]#011train-rmse:0.373828#011validation-rmse:0.391632
# [08:54:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 24 pruned nodes, max_depth=11
# [25]#011train-rmse:0.37106#011validation-rmse:0.389911
# [08:54:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 38 pruned nodes, max_depth=11
# [26]#011train-rmse:0.368888#011validation-rmse:0.388081
# [08:54:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 30 pruned nodes, max_depth=11
# [27]#011train-rmse:0.366785#011validation-rmse:0.38658
# [08:54:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 38 pruned nodes, max_depth=11
# [28]#011train-rmse:0.364513#011validation-rmse:0.385064
# [08:54:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 20 pruned nodes, max_depth=11
# [29]#011train-rmse:0.362378#011validation-rmse:0.383543
# [08:54:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 40 pruned nodes, max_depth=11
# [30]#011train-rmse:0.360448#011validation-rmse:0.382286
# [08:54:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 26 pruned nodes, max_depth=11
# [31]#011train-rmse:0.358331#011validation-rmse:0.380809
# [08:54:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 28 pruned nodes, max_depth=11
# [32]#011train-rmse:0.356553#011validation-rmse:0.379556
# [08:54:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 22 pruned nodes, max_depth=11
# [33]#011train-rmse:0.354838#011validation-rmse:0.378208
# [08:54:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 38 pruned nodes, max_depth=11
# [34]#011train-rmse:0.352677#011validation-rmse:0.376766
# [08:54:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 22 pruned nodes, max_depth=11
# [35]#011train-rmse:0.351169#011validation-rmse:0.375608
# [08:54:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 36 pruned nodes, max_depth=11
# [36]#011train-rmse:0.349498#011validation-rmse:0.374337
# [08:54:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 28 pruned nodes, max_depth=11
# [37]#011train-rmse:0.347668#011validation-rmse:0.372857
# [08:54:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 28 pruned nodes, max_depth=11
# [38]#011train-rmse:0.34619#011validation-rmse:0.371669
# [08:54:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 20 pruned nodes, max_depth=11
# [39]#011train-rmse:0.344505#011validation-rmse:0.370766
# [08:54:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 18 pruned nodes, max_depth=11
# [40]#011train-rmse:0.343006#011validation-rmse:0.36969
# [08:54:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 26 pruned nodes, max_depth=11
# [41]#011train-rmse:0.341498#011validation-rmse:0.368723
# [08:54:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 28 pruned nodes, max_depth=11
# [42]#011train-rmse:0.34038#011validation-rmse:0.367748
# [08:54:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 22 pruned nodes, max_depth=11
# [43]#011train-rmse:0.339045#011validation-rmse:0.366768
# [08:54:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 26 pruned nodes, max_depth=11
# [44]#011train-rmse:0.337498#011validation-rmse:0.365712
# [08:54:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 32 pruned nodes, max_depth=11
# [45]#011train-rmse:0.336016#011validation-rmse:0.364752
# [08:55:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 30 pruned nodes, max_depth=11
# [46]#011train-rmse:0.334564#011validation-rmse:0.363902
# [08:55:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 24 pruned nodes, max_depth=11
# [47]#011train-rmse:0.333271#011validation-rmse:0.362894
# [08:55:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 34 pruned nodes, max_depth=11
# [48]#011train-rmse:0.331633#011validation-rmse:0.362064
# [08:55:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 28 pruned nodes, max_depth=11
# [49]#011train-rmse:0.330154#011validation-rmse:0.361105
# [08:55:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 22 pruned nodes, max_depth=11
# [50]#011train-rmse:0.328894#011validation-rmse:0.360328
# [08:55:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 36 pruned nodes, max_depth=11
# [51]#011train-rmse:0.327203#011validation-rmse:0.359548
# [08:55:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 30 pruned nodes, max_depth=11
# [52]#011train-rmse:0.326059#011validation-rmse:0.358676
# [08:55:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 26 pruned nodes, max_depth=11
# [53]#011train-rmse:0.325001#011validation-rmse:0.357922
# [08:55:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 18 pruned nodes, max_depth=11
# [54]#011train-rmse:0.323762#011validation-rmse:0.357128
# [08:55:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 32 pruned nodes, max_depth=11
# [55]#011train-rmse:0.322598#011validation-rmse:0.356493
# [08:55:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 30 pruned nodes, max_depth=11
# [56]#011train-rmse:0.321553#011validation-rmse:0.355818
# [08:55:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 30 pruned nodes, max_depth=11
# [57]#011train-rmse:0.320469#011validation-rmse:0.354946
# [08:55:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 38 pruned nodes, max_depth=11
# [58]#011train-rmse:0.319295#011validation-rmse:0.354268
# [08:55:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 36 pruned nodes, max_depth=11
# [59]#011train-rmse:0.31791#011validation-rmse:0.353502
# [08:55:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 28 pruned nodes, max_depth=11
# [60]#011train-rmse:0.316819#011validation-rmse:0.352914
# [08:55:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 30 pruned nodes, max_depth=11
# [61]#011train-rmse:0.315929#011validation-rmse:0.352312
# [08:55:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 46 pruned nodes, max_depth=11
# [62]#011train-rmse:0.314916#011validation-rmse:0.35168
# [08:55:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 26 pruned nodes, max_depth=11
# [63]#011train-rmse:0.313722#011validation-rmse:0.35104
# [08:55:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 30 pruned nodes, max_depth=11
# [64]#011train-rmse:0.312791#011validation-rmse:0.35048
# [08:55:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 26 pruned nodes, max_depth=11
# [65]#011train-rmse:0.311622#011validation-rmse:0.349834
# [08:55:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 34 pruned nodes, max_depth=11
# [66]#011train-rmse:0.310485#011validation-rmse:0.349151
# [08:55:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 36 pruned nodes, max_depth=11
# [67]#011train-rmse:0.309674#011validation-rmse:0.348593
# [08:56:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 38 pruned nodes, max_depth=11
# [68]#011train-rmse:0.308681#011validation-rmse:0.348006
# [08:56:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 30 pruned nodes, max_depth=11
# [69]#011train-rmse:0.307527#011validation-rmse:0.347508
# [08:56:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 36 pruned nodes, max_depth=11
# [70]#011train-rmse:0.306688#011validation-rmse:0.346975
# [08:56:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 26 pruned nodes, max_depth=11
# [71]#011train-rmse:0.305825#011validation-rmse:0.346387
# [08:56:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 32 pruned nodes, max_depth=11
# [72]#011train-rmse:0.304879#011validation-rmse:0.345785
# [08:56:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 20 pruned nodes, max_depth=11
# [73]#011train-rmse:0.303845#011validation-rmse:0.345395
# [08:56:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 8 pruned nodes, max_depth=11
# [74]#011train-rmse:0.302859#011validation-rmse:0.344895
# [08:56:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 36 pruned nodes, max_depth=11
# [75]#011train-rmse:0.301748#011validation-rmse:0.344314
# [08:56:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 18 pruned nodes, max_depth=11
# [76]#011train-rmse:0.300779#011validation-rmse:0.343751
# [08:56:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 26 pruned nodes, max_depth=11
# [77]#011train-rmse:0.300096#011validation-rmse:0.343262
# [08:56:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 42 pruned nodes, max_depth=11
# [78]#011train-rmse:0.299208#011validation-rmse:0.3428
# [08:56:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 30 pruned nodes, max_depth=11
# [79]#011train-rmse:0.298396#011validation-rmse:0.342453
# [08:56:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 30 pruned nodes, max_depth=11
# [80]#011train-rmse:0.297592#011validation-rmse:0.341907
# [08:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 28 pruned nodes, max_depth=11
# [81]#011train-rmse:0.296942#011validation-rmse:0.341516
# [08:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 36 pruned nodes, max_depth=11
# [82]#011train-rmse:0.296156#011validation-rmse:0.341139
# [08:56:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 26 pruned nodes, max_depth=11
# [83]#011train-rmse:0.295392#011validation-rmse:0.340723
# [08:56:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 38 pruned nodes, max_depth=11
# [84]#011train-rmse:0.294477#011validation-rmse:0.340272
# [08:56:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 34 pruned nodes, max_depth=11
# [85]#011train-rmse:0.293713#011validation-rmse:0.339845
# [08:56:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 26 pruned nodes, max_depth=11
# [86]#011train-rmse:0.293082#011validation-rmse:0.33941
# [08:56:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 36 pruned nodes, max_depth=11
# [87]#011train-rmse:0.292271#011validation-rmse:0.338944
# [08:56:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 26 pruned nodes, max_depth=11
# [88]#011train-rmse:0.291621#011validation-rmse:0.338493
# [08:56:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 28 pruned nodes, max_depth=11
# [89]#011train-rmse:0.290852#011validation-rmse:0.338131
# [08:57:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 20 pruned nodes, max_depth=11
# [90]#011train-rmse:0.289865#011validation-rmse:0.337579
# [08:57:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 26 pruned nodes, max_depth=11
# [91]#011train-rmse:0.288915#011validation-rmse:0.337201
# [08:57:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 36 pruned nodes, max_depth=11
# [92]#011train-rmse:0.288204#011validation-rmse:0.336878
# [08:57:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 22 pruned nodes, max_depth=11
# [93]#011train-rmse:0.287518#011validation-rmse:0.33636
# [08:57:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 24 pruned nodes, max_depth=11
# [94]#011train-rmse:0.286681#011validation-rmse:0.335819
# [08:57:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 42 pruned nodes, max_depth=11
# [95]#011train-rmse:0.285937#011validation-rmse:0.335502
# [08:57:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 28 pruned nodes, max_depth=11
# [96]#011train-rmse:0.285302#011validation-rmse:0.33504
# [08:57:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 34 pruned nodes, max_depth=11
# [97]#011train-rmse:0.284776#011validation-rmse:0.334677
# [08:57:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 22 pruned nodes, max_depth=11
# [98]#011train-rmse:0.284196#011validation-rmse:0.334381
# [08:57:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 28 pruned nodes, max_depth=11
# [99]#011train-rmse:0.283662#011validation-rmse:0.334058
# [08:57:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 34 pruned nodes, max_depth=11
# [100]#011train-rmse:0.283023#011validation-rmse:0.33374
# [08:57:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 32 pruned nodes, max_depth=11
# [101]#011train-rmse:0.282493#011validation-rmse:0.333442
# [08:57:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 36 pruned nodes, max_depth=11
# [102]#011train-rmse:0.282047#011validation-rmse:0.333083
# [08:57:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 12 pruned nodes, max_depth=11
# [103]#011train-rmse:0.281457#011validation-rmse:0.332709
# [08:57:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 20 pruned nodes, max_depth=11
# [104]#011train-rmse:0.280638#011validation-rmse:0.332318
# [08:57:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 28 pruned nodes, max_depth=11
# [105]#011train-rmse:0.28004#011validation-rmse:0.33206
# [08:57:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 30 pruned nodes, max_depth=11
# [106]#011train-rmse:0.279469#011validation-rmse:0.331757
# [08:57:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 14 pruned nodes, max_depth=11
# [107]#011train-rmse:0.278919#011validation-rmse:0.331501
# [08:57:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 26 pruned nodes, max_depth=11
# [108]#011train-rmse:0.278178#011validation-rmse:0.331221
# [08:57:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 20 pruned nodes, max_depth=11
# [109]#011train-rmse:0.277556#011validation-rmse:0.330972
# [08:57:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 26 pruned nodes, max_depth=11
# [110]#011train-rmse:0.276964#011validation-rmse:0.330614
# [08:57:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 26 pruned nodes, max_depth=11
# [111]#011train-rmse:0.276032#011validation-rmse:0.330282
# [08:57:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 18 pruned nodes, max_depth=11
# [112]#011train-rmse:0.275405#011validation-rmse:0.32996
# [08:58:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 34 pruned nodes, max_depth=11
# [113]#011train-rmse:0.274982#011validation-rmse:0.329658
# [08:58:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 26 pruned nodes, max_depth=11
# [114]#011train-rmse:0.27428#011validation-rmse:0.329383
# [08:58:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 36 pruned nodes, max_depth=11
# [115]#011train-rmse:0.273768#011validation-rmse:0.329209
# [08:58:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 34 pruned nodes, max_depth=11
# [116]#011train-rmse:0.272952#011validation-rmse:0.328911
# [08:58:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 20 pruned nodes, max_depth=11
# [117]#011train-rmse:0.272552#011validation-rmse:0.328603
# [08:58:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 24 pruned nodes, max_depth=11
# [118]#011train-rmse:0.272147#011validation-rmse:0.32835
# [08:58:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 16 pruned nodes, max_depth=11
# [119]#011train-rmse:0.271645#011validation-rmse:0.328008
# [08:58:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 20 pruned nodes, max_depth=11
# [120]#011train-rmse:0.271134#011validation-rmse:0.327798
# [08:58:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 16 pruned nodes, max_depth=11
# [121]#011train-rmse:0.270728#011validation-rmse:0.327563
# [08:58:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 22 pruned nodes, max_depth=11
# [122]#011train-rmse:0.270321#011validation-rmse:0.327267
# [08:58:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 34 pruned nodes, max_depth=11
# [123]#011train-rmse:0.269654#011validation-rmse:0.327065
# [08:58:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 28 pruned nodes, max_depth=11
# [124]#011train-rmse:0.269084#011validation-rmse:0.326805
# [08:58:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 22 pruned nodes, max_depth=11
# [125]#011train-rmse:0.268621#011validation-rmse:0.32654
# [08:58:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 30 pruned nodes, max_depth=11
# [126]#011train-rmse:0.267901#011validation-rmse:0.326352
# [08:58:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 28 pruned nodes, max_depth=11
# [127]#011train-rmse:0.267492#011validation-rmse:0.326061
# [08:58:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 16 pruned nodes, max_depth=11
# [128]#011train-rmse:0.267103#011validation-rmse:0.325812
# [08:58:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 36 pruned nodes, max_depth=11
# [129]#011train-rmse:0.266165#011validation-rmse:0.325468
# [08:58:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 20 pruned nodes, max_depth=11
# [130]#011train-rmse:0.2656#011validation-rmse:0.325125
# [08:58:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 16 pruned nodes, max_depth=11
# [131]#011train-rmse:0.265273#011validation-rmse:0.324943
# [08:58:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 20 pruned nodes, max_depth=11
# [132]#011train-rmse:0.264823#011validation-rmse:0.324654
# [08:58:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 48 pruned nodes, max_depth=11
# [133]#011train-rmse:0.264134#011validation-rmse:0.324496
# [08:58:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 34 pruned nodes, max_depth=11
# [134]#011train-rmse:0.263286#011validation-rmse:0.324229
# [08:59:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 20 pruned nodes, max_depth=11
# [135]#011train-rmse:0.262845#011validation-rmse:0.32399
# [08:59:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 40 pruned nodes, max_depth=11
# [136]#011train-rmse:0.2623#011validation-rmse:0.323754
# [08:59:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 16 pruned nodes, max_depth=11
# [137]#011train-rmse:0.261923#011validation-rmse:0.323629
# [08:59:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 60 pruned nodes, max_depth=11
# [138]#011train-rmse:0.261418#011validation-rmse:0.323369
# [08:59:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 24 pruned nodes, max_depth=11
# [139]#011train-rmse:0.260937#011validation-rmse:0.323223
# [08:59:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 28 pruned nodes, max_depth=11
# [140]#011train-rmse:0.260475#011validation-rmse:0.32294
# [08:59:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 24 pruned nodes, max_depth=11
# [141]#011train-rmse:0.260177#011validation-rmse:0.322816
# [08:59:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 30 pruned nodes, max_depth=11
# [142]#011train-rmse:0.259754#011validation-rmse:0.322629
# [08:59:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 32 pruned nodes, max_depth=11
# [143]#011train-rmse:0.259287#011validation-rmse:0.322354
# [08:59:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 42 pruned nodes, max_depth=11
# [144]#011train-rmse:0.258736#011validation-rmse:0.322161
# [08:59:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 22 pruned nodes, max_depth=11
# [145]#011train-rmse:0.258459#011validation-rmse:0.322007
# [08:59:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 22 pruned nodes, max_depth=11
# [146]#011train-rmse:0.258072#011validation-rmse:0.321824
# [08:59:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 24 pruned nodes, max_depth=11
# [147]#011train-rmse:0.257607#011validation-rmse:0.321655
# [08:59:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 12 pruned nodes, max_depth=11
# [148]#011train-rmse:0.257201#011validation-rmse:0.321562
# [08:59:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 32 pruned nodes, max_depth=11
# [149]#011train-rmse:0.256759#011validation-rmse:0.321324
# [08:59:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 8 pruned nodes, max_depth=11
# [150]#011train-rmse:0.256399#011validation-rmse:0.321056
# [08:59:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 16 pruned nodes, max_depth=11
# [151]#011train-rmse:0.255911#011validation-rmse:0.320871
# [08:59:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 28 pruned nodes, max_depth=11
# [152]#011train-rmse:0.255386#011validation-rmse:0.320656
# [08:59:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 12 pruned nodes, max_depth=11
# [153]#011train-rmse:0.254946#011validation-rmse:0.320496
# [08:59:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 16 pruned nodes, max_depth=11
# [154]#011train-rmse:0.254571#011validation-rmse:0.32033
# [08:59:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 18 pruned nodes, max_depth=11
# [155]#011train-rmse:0.254173#011validation-rmse:0.320124
# [08:59:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 10 pruned nodes, max_depth=11
# [156]#011train-rmse:0.253854#011validation-rmse:0.3199
# [08:59:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 26 pruned nodes, max_depth=11
# [157]#011train-rmse:0.253529#011validation-rmse:0.319775
# [09:00:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 12 pruned nodes, max_depth=11
# [158]#011train-rmse:0.2532#011validation-rmse:0.319685
# [09:00:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 20 pruned nodes, max_depth=11
# [159]#011train-rmse:0.252949#011validation-rmse:0.319585
# [09:00:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 24 pruned nodes, max_depth=11
# [160]#011train-rmse:0.252504#011validation-rmse:0.31949
# [09:00:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 32 pruned nodes, max_depth=11
# [161]#011train-rmse:0.252038#011validation-rmse:0.319284
# [09:00:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 40 pruned nodes, max_depth=11
# [162]#011train-rmse:0.251503#011validation-rmse:0.319104
# [09:00:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 34 pruned nodes, max_depth=11
# [163]#011train-rmse:0.250991#011validation-rmse:0.318931
# [09:00:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 12 pruned nodes, max_depth=11
# [164]#011train-rmse:0.250565#011validation-rmse:0.318747
# [09:00:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 26 pruned nodes, max_depth=11
# [165]#011train-rmse:0.250146#011validation-rmse:0.318609
# [09:00:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 18 pruned nodes, max_depth=11
# [166]#011train-rmse:0.249657#011validation-rmse:0.318357
# [09:00:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 26 pruned nodes, max_depth=11
# [167]#011train-rmse:0.249341#011validation-rmse:0.318181
# [09:00:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 20 pruned nodes, max_depth=11
# [168]#011train-rmse:0.24906#011validation-rmse:0.318088
# [09:00:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 12 pruned nodes, max_depth=11
# [169]#011train-rmse:0.248636#011validation-rmse:0.317892
# [09:00:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 30 pruned nodes, max_depth=11
# [170]#011train-rmse:0.248088#011validation-rmse:0.317739
# [09:00:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 18 pruned nodes, max_depth=11
# [171]#011train-rmse:0.247729#011validation-rmse:0.31758
# [09:00:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 10 pruned nodes, max_depth=11
# [172]#011train-rmse:0.247282#011validation-rmse:0.317316
# [09:00:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 24 pruned nodes, max_depth=11
# [173]#011train-rmse:0.246643#011validation-rmse:0.317105
# [09:00:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 22 pruned nodes, max_depth=11
# [174]#011train-rmse:0.246254#011validation-rmse:0.316989
# [09:00:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 20 pruned nodes, max_depth=11
# [175]#011train-rmse:0.245953#011validation-rmse:0.316861
# [09:00:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 34 pruned nodes, max_depth=11
# [176]#011train-rmse:0.245442#011validation-rmse:0.316713
# [09:00:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 14 pruned nodes, max_depth=11
# [177]#011train-rmse:0.244904#011validation-rmse:0.316503
# [09:00:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 36 pruned nodes, max_depth=11
# [178]#011train-rmse:0.244449#011validation-rmse:0.3164
# [09:00:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 16 pruned nodes, max_depth=11
# [179]#011train-rmse:0.24399#011validation-rmse:0.316184
# [09:01:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 20 pruned nodes, max_depth=11
# [180]#011train-rmse:0.243731#011validation-rmse:0.316075
# [09:01:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 16 pruned nodes, max_depth=11
# [181]#011train-rmse:0.243322#011validation-rmse:0.315913
# [09:01:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 34 pruned nodes, max_depth=11
# [182]#011train-rmse:0.242942#011validation-rmse:0.315774
# [09:01:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 20 pruned nodes, max_depth=11
# [183]#011train-rmse:0.242633#011validation-rmse:0.315552
# [09:01:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 30 pruned nodes, max_depth=11
# [184]#011train-rmse:0.24234#011validation-rmse:0.315475
# [09:01:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 38 pruned nodes, max_depth=11
# [185]#011train-rmse:0.241972#011validation-rmse:0.315359
# [09:01:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 46 pruned nodes, max_depth=11
# [186]#011train-rmse:0.241393#011validation-rmse:0.315163
# [09:01:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 40 pruned nodes, max_depth=11
# [187]#011train-rmse:0.240662#011validation-rmse:0.314989
# [09:01:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 30 pruned nodes, max_depth=11
# [188]#011train-rmse:0.240413#011validation-rmse:0.31491
# [09:01:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 10 pruned nodes, max_depth=11
# [189]#011train-rmse:0.240181#011validation-rmse:0.314766
# [09:01:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 34 pruned nodes, max_depth=11
# [190]#011train-rmse:0.239825#011validation-rmse:0.314642
# [09:01:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 14 pruned nodes, max_depth=11
# [191]#011train-rmse:0.239374#011validation-rmse:0.314473
# [09:01:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 14 pruned nodes, max_depth=11
# [192]#011train-rmse:0.239009#011validation-rmse:0.314429
# [09:01:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 22 pruned nodes, max_depth=11
# [193]#011train-rmse:0.238709#011validation-rmse:0.314323
# [09:01:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 12 pruned nodes, max_depth=11
# [194]#011train-rmse:0.238481#011validation-rmse:0.31414
# [09:01:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 14 pruned nodes, max_depth=11
# [195]#011train-rmse:0.238207#011validation-rmse:0.314005
# [09:01:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 14 pruned nodes, max_depth=11
# [196]#011train-rmse:0.237928#011validation-rmse:0.313758
# [09:01:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 18 pruned nodes, max_depth=11
# [197]#011train-rmse:0.237728#011validation-rmse:0.313784
# [09:01:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 48 pruned nodes, max_depth=11
# [198]#011train-rmse:0.237365#011validation-rmse:0.31368
# [09:01:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 12 pruned nodes, max_depth=11
# [199]#011train-rmse:0.237071#011validation-rmse:0.3136
# [09:01:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 32 pruned nodes, max_depth=11
# [200]#011train-rmse:0.23664#011validation-rmse:0.3135
# [09:01:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 10 pruned nodes, max_depth=11
# [201]#011train-rmse:0.236425#011validation-rmse:0.313285
# [09:02:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 32 pruned nodes, max_depth=11
# [202]#011train-rmse:0.236098#011validation-rmse:0.313201
# [09:02:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 12 pruned nodes, max_depth=11
# [203]#011train-rmse:0.235848#011validation-rmse:0.313097
# [09:02:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 20 pruned nodes, max_depth=11
# [204]#011train-rmse:0.235458#011validation-rmse:0.312992
# [09:02:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 24 pruned nodes, max_depth=11
# [205]#011train-rmse:0.235233#011validation-rmse:0.312827
# [09:02:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 26 pruned nodes, max_depth=11
# [206]#011train-rmse:0.234866#011validation-rmse:0.312764
# [09:02:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 30 pruned nodes, max_depth=11
# [207]#011train-rmse:0.234577#011validation-rmse:0.312619
# [09:02:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 32 pruned nodes, max_depth=11
# [208]#011train-rmse:0.234148#011validation-rmse:0.312515
# [09:02:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 36 pruned nodes, max_depth=11
# [209]#011train-rmse:0.233639#011validation-rmse:0.312414
# [09:02:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 14 pruned nodes, max_depth=11
# [210]#011train-rmse:0.233471#011validation-rmse:0.312312
# [09:02:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 12 pruned nodes, max_depth=11
# [211]#011train-rmse:0.23331#011validation-rmse:0.312253
# [09:02:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 24 pruned nodes, max_depth=11
# [212]#011train-rmse:0.233073#011validation-rmse:0.312131
# [09:02:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 12 pruned nodes, max_depth=11
# [213]#011train-rmse:0.232797#011validation-rmse:0.312043
# [09:02:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 34 pruned nodes, max_depth=11
# [214]#011train-rmse:0.232397#011validation-rmse:0.311888
# [09:02:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 36 pruned nodes, max_depth=11
# [215]#011train-rmse:0.232109#011validation-rmse:0.311807
# [09:02:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 18 pruned nodes, max_depth=11
# [216]#011train-rmse:0.231918#011validation-rmse:0.311711
# [09:02:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 24 pruned nodes, max_depth=11
# [217]#011train-rmse:0.231659#011validation-rmse:0.311621
# [09:02:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 24 pruned nodes, max_depth=11
# [218]#011train-rmse:0.231269#011validation-rmse:0.311551
# [09:02:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 12 pruned nodes, max_depth=11
# [219]#011train-rmse:0.230993#011validation-rmse:0.311445
# [09:02:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 16 pruned nodes, max_depth=11
# [220]#011train-rmse:0.23075#011validation-rmse:0.311366
# [09:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 22 pruned nodes, max_depth=11
# [221]#011train-rmse:0.230581#011validation-rmse:0.311319
# [09:02:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 32 pruned nodes, max_depth=11
# [222]#011train-rmse:0.23029#011validation-rmse:0.311188
# [09:02:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 32 pruned nodes, max_depth=11
# [223]#011train-rmse:0.229807#011validation-rmse:0.311027
# [09:03:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 48 pruned nodes, max_depth=11
# [224]#011train-rmse:0.229471#011validation-rmse:0.310947
# [09:03:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 18 pruned nodes, max_depth=11
# [225]#011train-rmse:0.229221#011validation-rmse:0.310821
# [09:03:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 42 pruned nodes, max_depth=11
# [226]#011train-rmse:0.228859#011validation-rmse:0.310754
# [09:03:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 22 pruned nodes, max_depth=11
# [227]#011train-rmse:0.228433#011validation-rmse:0.310675
# [09:03:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 18 pruned nodes, max_depth=11
# [228]#011train-rmse:0.228199#011validation-rmse:0.310577
# [09:03:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 30 pruned nodes, max_depth=11
# [229]#011train-rmse:0.227807#011validation-rmse:0.310479
# [09:03:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 18 pruned nodes, max_depth=11
# [230]#011train-rmse:0.227598#011validation-rmse:0.310419
# [09:03:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 14 pruned nodes, max_depth=11
# [231]#011train-rmse:0.227265#011validation-rmse:0.310295
# [09:03:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 14 pruned nodes, max_depth=11
# [232]#011train-rmse:0.227068#011validation-rmse:0.310144
# [09:03:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 12 pruned nodes, max_depth=11
# [233]#011train-rmse:0.226904#011validation-rmse:0.310066
# [09:03:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 22 pruned nodes, max_depth=11
# [234]#011train-rmse:0.226536#011validation-rmse:0.30999
# [09:03:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 32 pruned nodes, max_depth=11
# [235]#011train-rmse:0.226224#011validation-rmse:0.309871
# [09:03:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 36 pruned nodes, max_depth=11
# [236]#011train-rmse:0.225988#011validation-rmse:0.30977
# [09:03:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 20 pruned nodes, max_depth=11
# [237]#011train-rmse:0.225831#011validation-rmse:0.309775
# [09:03:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 24 pruned nodes, max_depth=11
# [238]#011train-rmse:0.225618#011validation-rmse:0.309666
# [09:03:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 36 pruned nodes, max_depth=11
# [239]#011train-rmse:0.225284#011validation-rmse:0.309612
# [09:03:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 28 pruned nodes, max_depth=11
# [240]#011train-rmse:0.225#011validation-rmse:0.30954
# [09:03:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 24 pruned nodes, max_depth=11
# [241]#011train-rmse:0.22474#011validation-rmse:0.309481
# [09:03:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 24 pruned nodes, max_depth=11
# [242]#011train-rmse:0.224533#011validation-rmse:0.309377
# [09:03:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 6 pruned nodes, max_depth=11
# [243]#011train-rmse:0.224334#011validation-rmse:0.309304
# [09:03:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 30 pruned nodes, max_depth=11
# [244]#011train-rmse:0.224107#011validation-rmse:0.309247
# [09:03:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 10 pruned nodes, max_depth=11
# [245]#011train-rmse:0.223946#011validation-rmse:0.309222
# [09:03:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 20 pruned nodes, max_depth=11
# [246]#011train-rmse:0.223599#011validation-rmse:0.309157
# [09:04:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 48 pruned nodes, max_depth=11
# [247]#011train-rmse:0.223259#011validation-rmse:0.30898
# [09:04:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 24 pruned nodes, max_depth=11
# [248]#011train-rmse:0.222774#011validation-rmse:0.308802
# [09:04:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 22 pruned nodes, max_depth=11
# [249]#011train-rmse:0.22249#011validation-rmse:0.308686
# [09:04:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 32 pruned nodes, max_depth=11
# [250]#011train-rmse:0.222006#011validation-rmse:0.3086
# [09:04:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 16 pruned nodes, max_depth=11
# [251]#011train-rmse:0.221768#011validation-rmse:0.308487
# [09:04:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 28 pruned nodes, max_depth=11
# [252]#011train-rmse:0.221368#011validation-rmse:0.3084
# [09:04:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 12 pruned nodes, max_depth=11
# [253]#011train-rmse:0.221124#011validation-rmse:0.308365
# [09:04:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 22 pruned nodes, max_depth=11
# [254]#011train-rmse:0.220714#011validation-rmse:0.308224
# [09:04:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 18 pruned nodes, max_depth=11
# [255]#011train-rmse:0.220493#011validation-rmse:0.308064
# [09:04:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 12 pruned nodes, max_depth=11
# [256]#011train-rmse:0.220347#011validation-rmse:0.30799
# [09:04:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 32 pruned nodes, max_depth=11
# [257]#011train-rmse:0.22015#011validation-rmse:0.307908
# [09:04:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 36 pruned nodes, max_depth=11
# [258]#011train-rmse:0.219934#011validation-rmse:0.307863
# [09:04:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 24 pruned nodes, max_depth=11
# [259]#011train-rmse:0.219715#011validation-rmse:0.307817
# [09:04:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 40 pruned nodes, max_depth=11
# [260]#011train-rmse:0.219446#011validation-rmse:0.307836
# [09:04:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 18 pruned nodes, max_depth=11
# [261]#011train-rmse:0.219107#011validation-rmse:0.307805
# [09:04:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 28 pruned nodes, max_depth=11
# [262]#011train-rmse:0.218914#011validation-rmse:0.307717
# [09:04:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 8 pruned nodes, max_depth=11
# [263]#011train-rmse:0.218762#011validation-rmse:0.307643
# [09:04:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 22 pruned nodes, max_depth=11
# [264]#011train-rmse:0.218521#011validation-rmse:0.307654
# [09:04:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 8 pruned nodes, max_depth=11
# [265]#011train-rmse:0.218313#011validation-rmse:0.30758
# [09:04:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 12 pruned nodes, max_depth=11
# [266]#011train-rmse:0.21804#011validation-rmse:0.30757
# [09:04:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 16 pruned nodes, max_depth=11
# [267]#011train-rmse:0.217818#011validation-rmse:0.307495
# [09:04:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 22 pruned nodes, max_depth=11
# [268]#011train-rmse:0.217463#011validation-rmse:0.307375
# [09:05:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 20 pruned nodes, max_depth=11
# [269]#011train-rmse:0.217313#011validation-rmse:0.307247
# [09:05:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 18 pruned nodes, max_depth=11
# [270]#011train-rmse:0.217131#011validation-rmse:0.307141
# [09:05:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 18 pruned nodes, max_depth=11
# [271]#011train-rmse:0.216922#011validation-rmse:0.306986
# [09:05:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 44 pruned nodes, max_depth=11
# [272]#011train-rmse:0.216519#011validation-rmse:0.306939
# [09:05:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 40 pruned nodes, max_depth=11
# [273]#011train-rmse:0.216305#011validation-rmse:0.306852
# ...
# [406]#011train-rmse:0.190529#011validation-rmse:0.300748
# [09:11:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 2 pruned nodes, max_depth=11
# [407]#011train-rmse:0.190415#011validation-rmse:0.300667
# [09:11:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 28 pruned nodes, max_depth=11
# [408]#011train-rmse:0.190278#011validation-rmse:0.300654
# [09:11:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 24 pruned nodes, max_depth=11
# [409]#011train-rmse:0.190192#011validation-rmse:0.300662
# [09:11:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 4 pruned nodes, max_depth=11
# [410]#011train-rmse:0.19005#011validation-rmse:0.300604
# [09:11:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 16 pruned nodes, max_depth=11
# [411]#011train-rmse:0.18989#011validation-rmse:0.300521
# [09:11:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 10 pruned nodes, max_depth=11
# [412]#011train-rmse:0.189774#011validation-rmse:0.300453
# [09:11:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 22 pruned nodes, max_depth=11
# [413]#011train-rmse:0.189555#011validation-rmse:0.300433
# [09:11:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 24 pruned nodes, max_depth=11
# [414]#011train-rmse:0.189363#011validation-rmse:0.30039
# [09:11:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 30 pruned nodes, max_depth=11
# [415]#011train-rmse:0.189092#011validation-rmse:0.300409
# [09:11:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 30 pruned nodes, max_depth=11
# [416]#011train-rmse:0.188986#011validation-rmse:0.300395
# [09:11:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 16 pruned nodes, max_depth=11
# [417]#011train-rmse:0.188751#011validation-rmse:0.300319
# [09:11:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 16 pruned nodes, max_depth=11
# [418]#011train-rmse:0.188637#011validation-rmse:0.300311
# [09:11:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 18 pruned nodes, max_depth=11
# [419]#011train-rmse:0.188525#011validation-rmse:0.300249
# [09:11:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 12 pruned nodes, max_depth=11
# [420]#011train-rmse:0.188344#011validation-rmse:0.300281
# [09:11:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 14 pruned nodes, max_depth=11
# [421]#011train-rmse:0.188234#011validation-rmse:0.300259
# [09:11:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 14 pruned nodes, max_depth=11
# [422]#011train-rmse:0.188124#011validation-rmse:0.300238
# [09:11:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 24 pruned nodes, max_depth=11
# [423]#011train-rmse:0.188047#011validation-rmse:0.300235
# [09:11:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 38 pruned nodes, max_depth=11
# [424]#011train-rmse:0.187853#011validation-rmse:0.300274
# [09:12:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 22 pruned nodes, max_depth=11
# [425]#011train-rmse:0.187762#011validation-rmse:0.300216
# [09:12:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 18 pruned nodes, max_depth=11
# [426]#011train-rmse:0.187531#011validation-rmse:0.300191
# [09:12:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 14 pruned nodes, max_depth=11
# [427]#011train-rmse:0.187402#011validation-rmse:0.300149
# [09:12:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 28 pruned nodes, max_depth=11
# [428]#011train-rmse:0.187163#011validation-rmse:0.300117
# [09:12:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 18 pruned nodes, max_depth=11
# [429]#011train-rmse:0.186953#011validation-rmse:0.30011
# [09:12:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 18 pruned nodes, max_depth=11
# [430]#011train-rmse:0.186696#011validation-rmse:0.300068
# [09:12:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 28 pruned nodes, max_depth=11
# [431]#011train-rmse:0.186606#011validation-rmse:0.299992
# [09:12:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 36 pruned nodes, max_depth=11
# [432]#011train-rmse:0.186389#011validation-rmse:0.299965
# [09:12:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 14 pruned nodes, max_depth=11
# [433]#011train-rmse:0.186223#011validation-rmse:0.299909
# [09:12:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 22 pruned nodes, max_depth=11
# [434]#011train-rmse:0.186084#011validation-rmse:0.299929
# [09:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 32 pruned nodes, max_depth=11
# [435]#011train-rmse:0.185853#011validation-rmse:0.299943
# [09:12:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 14 pruned nodes, max_depth=11
# [436]#011train-rmse:0.185732#011validation-rmse:0.299867
# [09:12:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 10 pruned nodes, max_depth=11
# [437]#011train-rmse:0.185585#011validation-rmse:0.299808
# [09:12:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 14 pruned nodes, max_depth=11
# [438]#011train-rmse:0.185432#011validation-rmse:0.299811
# [09:12:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 16 pruned nodes, max_depth=11
# [439]#011train-rmse:0.185356#011validation-rmse:0.299781
# [09:12:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 20 pruned nodes, max_depth=11
# [440]#011train-rmse:0.185247#011validation-rmse:0.299741
# [09:12:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 24 pruned nodes, max_depth=11
# [441]#011train-rmse:0.185096#011validation-rmse:0.299658
# [09:12:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 30 pruned nodes, max_depth=11
# [442]#011train-rmse:0.184953#011validation-rmse:0.299592
# [09:12:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 4 pruned nodes, max_depth=11
# [443]#011train-rmse:0.184861#011validation-rmse:0.299536
# [09:12:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 32 pruned nodes, max_depth=11
# [444]#011train-rmse:0.184748#011validation-rmse:0.299511
# [09:12:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 16 pruned nodes, max_depth=11
# [445]#011train-rmse:0.184685#011validation-rmse:0.299524
# [09:12:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 26 pruned nodes, max_depth=11
# [446]#011train-rmse:0.184442#011validation-rmse:0.299537
# [09:13:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 10 pruned nodes, max_depth=11
# [447]#011train-rmse:0.184354#011validation-rmse:0.299519
# [09:13:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 6 pruned nodes, max_depth=11
# [448]#011train-rmse:0.184214#011validation-rmse:0.299515
# [09:13:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 36 pruned nodes, max_depth=11
# [449]#011train-rmse:0.183992#011validation-rmse:0.299482
# [09:13:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 8 pruned nodes, max_depth=11
# [450]#011train-rmse:0.183885#011validation-rmse:0.299415
# [09:13:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 22 pruned nodes, max_depth=11
# [451]#011train-rmse:0.183609#011validation-rmse:0.299366
# [09:13:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 20 pruned nodes, max_depth=11
# [452]#011train-rmse:0.183458#011validation-rmse:0.299401
# [09:13:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 28 pruned nodes, max_depth=11
# [453]#011train-rmse:0.183323#011validation-rmse:0.299428
# [09:13:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 8 pruned nodes, max_depth=11
# [454]#011train-rmse:0.183238#011validation-rmse:0.299445
# [09:13:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 36 pruned nodes, max_depth=11
# [455]#011train-rmse:0.183077#011validation-rmse:0.299434
# [09:13:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 20 pruned nodes, max_depth=11
# [456]#011train-rmse:0.182953#011validation-rmse:0.299468
# [09:13:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 20 pruned nodes, max_depth=11
# [457]#011train-rmse:0.1828#011validation-rmse:0.299442
# [09:13:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 24 pruned nodes, max_depth=11
# [458]#011train-rmse:0.182523#011validation-rmse:0.299434
# [09:13:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 12 pruned nodes, max_depth=11
# [459]#011train-rmse:0.182438#011validation-rmse:0.299423
# [09:13:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 30 pruned nodes, max_depth=11
# [460]#011train-rmse:0.18226#011validation-rmse:0.299402
# [09:13:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 18 pruned nodes, max_depth=11
# [461]#011train-rmse:0.182146#011validation-rmse:0.299356
# [09:13:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 48 pruned nodes, max_depth=11
# [462]#011train-rmse:0.181844#011validation-rmse:0.299312
# [09:13:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 20 pruned nodes, max_depth=11
# [463]#011train-rmse:0.181725#011validation-rmse:0.299274
# [09:13:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 40 pruned nodes, max_depth=11
# [464]#011train-rmse:0.181463#011validation-rmse:0.299258
# [09:13:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 40 pruned nodes, max_depth=11
# [465]#011train-rmse:0.181246#011validation-rmse:0.299248
# [09:13:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 36 pruned nodes, max_depth=11
# [466]#011train-rmse:0.181096#011validation-rmse:0.299237
# [09:13:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 14 pruned nodes, max_depth=11
# [467]#011train-rmse:0.181#011validation-rmse:0.299227
# [09:13:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 36 pruned nodes, max_depth=11
# [468]#011train-rmse:0.18094#011validation-rmse:0.299224
# [09:14:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 20 pruned nodes, max_depth=11
# [469]#011train-rmse:0.180872#011validation-rmse:0.29919
# [09:14:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 22 pruned nodes, max_depth=11
# [470]#011train-rmse:0.180778#011validation-rmse:0.299206
# [09:14:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 20 pruned nodes, max_depth=11
# [471]#011train-rmse:0.1807#011validation-rmse:0.299203
# [09:14:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 12 pruned nodes, max_depth=11
# [472]#011train-rmse:0.180564#011validation-rmse:0.299197
# [09:14:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 14 pruned nodes, max_depth=11
# [473]#011train-rmse:0.180455#011validation-rmse:0.299186
# [09:14:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 8 pruned nodes, max_depth=11
# [474]#011train-rmse:0.180335#011validation-rmse:0.299204
# [09:14:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 26 pruned nodes, max_depth=11
# [475]#011train-rmse:0.180212#011validation-rmse:0.29917
# [09:14:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 16 pruned nodes, max_depth=11
# [476]#011train-rmse:0.180111#011validation-rmse:0.299168
# [09:14:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 36 pruned nodes, max_depth=11
# [477]#011train-rmse:0.179995#011validation-rmse:0.299127
# [09:14:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 28 pruned nodes, max_depth=11
# [478]#011train-rmse:0.17986#011validation-rmse:0.299152
# [09:14:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 14 pruned nodes, max_depth=11
# [479]#011train-rmse:0.179732#011validation-rmse:0.299124
# [09:14:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 20 pruned nodes, max_depth=11
# [480]#011train-rmse:0.179657#011validation-rmse:0.299115
# [09:14:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 26 pruned nodes, max_depth=11
# [481]#011train-rmse:0.179476#011validation-rmse:0.299031
# [09:14:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 38 pruned nodes, max_depth=11
# [482]#011train-rmse:0.179385#011validation-rmse:0.299015
# [09:14:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 2 pruned nodes, max_depth=11
# [483]#011train-rmse:0.179303#011validation-rmse:0.299017
# [09:14:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 14 pruned nodes, max_depth=11
# [484]#011train-rmse:0.179209#011validation-rmse:0.298953
# [09:14:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 28 pruned nodes, max_depth=11
# [485]#011train-rmse:0.179119#011validation-rmse:0.298936
# [09:14:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 20 pruned nodes, max_depth=11
# [486]#011train-rmse:0.179018#011validation-rmse:0.298902
# [09:14:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 22 pruned nodes, max_depth=11
# [487]#011train-rmse:0.178933#011validation-rmse:0.298921
# [09:14:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 10 pruned nodes, max_depth=11
# [488]#011train-rmse:0.178869#011validation-rmse:0.298896
# [09:14:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 28 pruned nodes, max_depth=11
# [489]#011train-rmse:0.178714#011validation-rmse:0.298911
# [09:14:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 14 pruned nodes, max_depth=10
# [490]#011train-rmse:0.178651#011validation-rmse:0.298818
# [09:14:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 20 pruned nodes, max_depth=11
# [491]#011train-rmse:0.178553#011validation-rmse:0.298813
# [09:15:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 24 pruned nodes, max_depth=11
# [492]#011train-rmse:0.178373#011validation-rmse:0.298768
# [09:15:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 36 pruned nodes, max_depth=11
# [493]#011train-rmse:0.17824#011validation-rmse:0.298714
# [09:15:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 26 pruned nodes, max_depth=11
# [494]#011train-rmse:0.178136#011validation-rmse:0.298703
# [09:15:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 14 pruned nodes, max_depth=11
# [495]#011train-rmse:0.177901#011validation-rmse:0.298706
# [09:15:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 22 pruned nodes, max_depth=11
# [496]#011train-rmse:0.177781#011validation-rmse:0.29874
# [09:15:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 20 pruned nodes, max_depth=11
# [497]#011train-rmse:0.177705#011validation-rmse:0.298731
# [09:15:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 14 pruned nodes, max_depth=11
# [498]#011train-rmse:0.177571#011validation-rmse:0.298733
# [09:15:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 16 pruned nodes, max_depth=11
# [499]#011train-rmse:0.177493#011validation-rmse:0.298666
# Billable seconds: 1391

# %% [markdown]
# Now that we have an estimator object attached to the correct training job, we can proceed as we normally would and create a transformer object.

# %%
# TODO: Create a transformer object from the attached estimator. Using an instance count of 1 and an instance type of ml.m4.xlarge
#       should be more than enough.

xgb_transformer = xgb_attached.transformer(instance_count = 1, instance_type = 'ml.m4.xlarge')
# Out:
# INFO:sagemaker:Creating model with name: xgboost-181012-0648-020-4f5ca2dd

# %% [markdown]
# Next we actually perform the transform job. When doing so we need to make sure to specify the type of data we are sending so that it is serialized correctly in the background. In our case we are providing our model with csv data so we specify `text/csv`. Also, if the test data that we have provided is too large to process all at once then we need to specify how the data file should be split up. Since each line is a single entry in our data set we tell SageMaker that it can split the input on each line.

# %%
# TODO: Start the transform job. Make sure to specify the content type and the split type of the test data.
xgb_transformer.transform(test_location, content_type='text/csv', split_type='Line')
# Out:
# INFO:sagemaker:Created S3 bucket: sagemaker-us-east-1-440180731255
# INFO:sagemaker:Creating transform job with name: xgboost-181012-0648-020-4f5ca2dd-2018-10-12-13-33-27-831

# %% [markdown]
# Currently the transform job is running but it is doing so in the background. Since we wish to wait until the transform job is done and we would like a bit of feedback we can run the `wait()` method.

# %%
xgb_transformer.wait()
# Out:
# .........................................!

# %% [markdown]
# Now the transform job has executed and the result, the estimated sentiment of each review, has been saved on S3. Since we would rather work on this file locally we can perform a bit of notebook magic to copy the file to the `data_dir`.

# %%
# !aws s3 cp --recursive $xgb_transformer.output_path $data_dir
# Out:
# download: s3://sagemaker-us-east-1-440180731255/xgboost-181012-0648-020-4f5ca2dd-2018-10-12-13-33-27-831/test.csv.out to ../data/xgboost/test.csv.out

# %% [markdown]
# The last step is now to read in the output from our model, convert the output to something a little more usable, in this case we want the sentiment to be either `1` (positive) or `0` (negative), and then compare to the ground truth labels.

# %%
predictions = pd.read_csv(os.path.join(data_dir, 'test.csv.out'), header=None)
predictions = [round(num) for num in predictions.squeeze().values]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_y, predictions)
# Out:
# 0.87396

# %% [markdown]
# ## Optional: Clean up
#
# The default notebook instance on SageMaker doesn't have a lot of excess disk space available. As you continue to complete and execute notebooks you will eventually fill up this disk space, leading to errors which can be difficult to diagnose. Once you are completely finished using a notebook it is a good idea to remove the files that you created along the way. Of course, you can do this from the terminal or from the notebook hub if you would like. The cell below contains some commands to clean up the created files from within the notebook.

# %%
# First we will remove all of the files contained in the data_dir directory
# !rm $data_dir/*

# And then we delete the directory itself
# !rmdir $data_dir

# Similarly we will remove the files in the cache_dir directory and the directory itself
# !rm $cache_dir/*
# !rmdir $cache_dir
